# %% [markdown]
# # Exploratory Analysis
#
# Quick sanity checks for the phishing email dataset.

# %%
from pathlib import Path
import pandas as pd

DATA = Path('..') / 'data' / 'phishing_emails.csv'
if DATA.exists():
    df = pd.read_csv(DATA)
    print(df.head())
    print('\nLabel distribution:')
    print(df['label'].value_counts(normalize=True))
else:
    print('Dataset not found. Place phishing_emails.csv under data/.')
